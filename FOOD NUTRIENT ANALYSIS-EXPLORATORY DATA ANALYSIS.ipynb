# %% [markdown]
# FOOD NUTRIENT ANALYSIS
#
# PROJECT EXPLORATORY DATA ANALYSIS ON FOOD NUTRIENT ANALYSIS BY MAUZUM SHAMIL

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\dell\Desktop\food nutrient dataset.csv")

# %%
df
# Out:
#          ID                 Description  Calories  Protein  TotalFat  \
# 0      1001            BUTTER,WITH SALT     717.0     0.85     81.11
# 1      1002    BUTTER,WHIPPED,WITH SALT     717.0     0.85     81.11
# 2      1003        BUTTER OIL,ANHYDROUS     876.0     0.28     99.48
# 3      1004                 CHEESE,BLUE     353.0    21.40     28.74
# 4      1005                CHEESE,BRICK     371.0    23.24     29.68
# ...     ...                         ...       ...      ...       ...
# 7053  80200               FROG LEGS,RAW      73.0    16.40      0.30
# 7054  83110             MACKEREL,SALTED     305.0    18.50     25.10
# 7055  90240  SCALLOP,(BAY&SEA),CKD,STMD     111.0    20.54      0.84
# 7056  90560                   SNAIL,RAW      90.0    16.10      1.40
# 7057  93600            TURTLE,GREEN,RAW      89.0    19.80      0.50
#
#       Carbohydrate  Sodium  SaturatedFat  Cholesterol  Sugar  Calcium  Iron  \
# ...

# %% [markdown]
# # Exploitory data analysis

# %%
df.head(10)
# Out:
#      ID               Description  Calories  Protein  TotalFat  Carbohydrate  \
# 0  1001          BUTTER,WITH SALT     717.0     0.85     81.11          0.06
# 1  1002  BUTTER,WHIPPED,WITH SALT     717.0     0.85     81.11          0.06
# 2  1003      BUTTER OIL,ANHYDROUS     876.0     0.28     99.48          0.00
# 3  1004               CHEESE,BLUE     353.0    21.40     28.74          2.34
# 4  1005              CHEESE,BRICK     371.0    23.24     29.68          2.79
# 5  1006               CHEESE,BRIE     334.0    20.75     27.68          0.45
# 6  1007          CHEESE,CAMEMBERT     300.0    19.80     24.26          0.46
# 7  1008            CHEESE,CARAWAY     376.0    25.18     29.20          3.06
# 8  1009            CHEESE,CHEDDAR     403.0    24.90     33.14          1.28
# 9  1010           CHEESE,CHESHIRE     387.0    23.37     30.60          4.78
#
#    Sodium  SaturatedFat  Cholesterol  Sugar  Calcium  Iron  Potassium  \
# ...

# %%
df.tail(10)
# Out:
#          ID                                        Description  Calories  \
# 7048  44203               COCKTAIL MIX,NON-ALCOHOLIC,CONCD,FRZ     287.0
# 7049  44258            PUDDINGS,CHOC FLAVOR,LO CAL,REG,DRY MIX     365.0
# 7050  44259  PUDDINGS,ALL FLAVORS XCPT CHOC,LO CAL,REG,DRY MIX     351.0
# 7051  44260  PUDDINGS,ALL FLAVORS XCPT CHOC,LO CAL,INST,DRY...     350.0
# 7052  48052                                 VITAL WHEAT GLUTEN     370.0
# 7053  80200                                      FROG LEGS,RAW      73.0
# 7054  83110                                    MACKEREL,SALTED     305.0
# 7055  90240                         SCALLOP,(BAY&SEA),CKD,STMD     111.0
# 7056  90560                                          SNAIL,RAW      90.0
# 7057  93600                                   TURTLE,GREEN,RAW      89.0
#
#       Protein  TotalFat  Carbohydrate  Sodium  SaturatedFat  Cholesterol  \
# 7048     0.08      0.01         71.60     0.0         0.003          0.0
# ...

# %%
df[40:50]
# Out:
#       ID                                     Description  Calories  Protein  \
# 40  1041                                   CHEESE,TILSIT     340.0    24.41
# 41  1042  CHEESE,PAST PROCESS,AMERICAN,FORT W/ VITAMIN D     371.0    18.13
# 42  1043                     CHEESE,PAST PROCESS,PIMENTO     375.0    22.13
# 43  1044                       CHEESE,PAST PROCESS,SWISS     334.0    24.73
# 44  1045                      CHEESE FD,COLD PK,AMERICAN     331.0    19.66
# 45  1046  CHEESE FD,PAST PROCESS,AMERICAN,VITAMIN D FORT     330.0    16.86
# 46  1047                    CHEESE FD,PAST PROCESS,SWISS     323.0    21.92
# 47  1048               CHEESE SPRD,PAST PROCESS,AMERICAN     290.0    16.41
# 48  1049                       CREAM,FLUID,HALF AND HALF     130.0     2.96
# 49  1050        CREAM,FLUID,LT (COFFEE CRM OR TABLE CRM)     195.0     2.70
#
#     TotalFat  Carbohydrate  Sodium  SaturatedFat  Cholesterol  Sugar  Calcium  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7058 entries, 0 to 7057
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            7058 non-null   int64
#  1   Description   7058 non-null   object
#  2   Calories      7057 non-null   float64
#  3   Protein       7057 non-null   float64
#  4   TotalFat      7057 non-null   float64
#  5   Carbohydrate  7057 non-null   float64
#  6   Sodium        6974 non-null   float64
#  7   SaturatedFat  6757 non-null   float64
#  8   Cholesterol   6770 non-null   float64
#  9   Sugar         5148 non-null   float64
#  10  Calcium       6922 non-null   float64
#  11  Iron          6935 non-null   float64
#  12  Potassium     6649 non-null   float64
#  13  VitaminC      6726 non-null   float64
#  14  VitaminE      4338 non-null   float64
#  15  VitaminD      4224 non-null   float64
# dtypes: float64(14), int64(1), object(1)
# memory usage: 882.4+ KB

# %%
df.dtypes
# Out:
# ID                int64
# Description      object
# Calories        float64
# Protein         float64
# TotalFat        float64
# Carbohydrate    float64
# Sodium          float64
# SaturatedFat    float64
# Cholesterol     float64
# Sugar           float64
# Calcium         float64
# Iron            float64
# Potassium       float64
# VitaminC        float64
# VitaminE        float64
# VitaminD        float64
# dtype: object

# %%
df.columns
# Out:
# Index(['ID', 'Description', 'Calories', 'Protein', 'TotalFat', 'Carbohydrate',
#        'Sodium', 'SaturatedFat', 'Cholesterol', 'Sugar', 'Calcium', 'Iron',
#        'Potassium', 'VitaminC', 'VitaminE', 'VitaminD'],
#       dtype='object')

# %%
df = df.drop('ID',axis=1)

# %%
df
# Out:
#                      Description  Calories  Protein  TotalFat  Carbohydrate  \
# 0               BUTTER,WITH SALT     717.0     0.85     81.11          0.06
# 1       BUTTER,WHIPPED,WITH SALT     717.0     0.85     81.11          0.06
# 2           BUTTER OIL,ANHYDROUS     876.0     0.28     99.48          0.00
# 3                    CHEESE,BLUE     353.0    21.40     28.74          2.34
# 4                   CHEESE,BRICK     371.0    23.24     29.68          2.79
# ...                          ...       ...      ...       ...           ...
# 7053               FROG LEGS,RAW      73.0    16.40      0.30          0.00
# 7054             MACKEREL,SALTED     305.0    18.50     25.10          0.00
# 7055  SCALLOP,(BAY&SEA),CKD,STMD     111.0    20.54      0.84          5.41
# 7056                   SNAIL,RAW      90.0    16.10      1.40          2.00
# 7057            TURTLE,GREEN,RAW      89.0    19.80      0.50          0.00
#
# ...

# %% [markdown]
# # data visualization

# %%
plt.plot(df['TotalFat'],df['SaturatedFat'],'r*')

# %%
plt.figure(figsize=(10, 10))
df.hist()
# Out:
# array([[<Axes: title={'center': 'Calories'}>,
#         <Axes: title={'center': 'Protein'}>,
#         <Axes: title={'center': 'TotalFat'}>,
#         <Axes: title={'center': 'Carbohydrate'}>],
#        [<Axes: title={'center': 'Sodium'}>,
#         <Axes: title={'center': 'SaturatedFat'}>,
#         <Axes: title={'center': 'Cholesterol'}>,
#         <Axes: title={'center': 'Sugar'}>],
#        [<Axes: title={'center': 'Calcium'}>,
#         <Axes: title={'center': 'Iron'}>,
#         <Axes: title={'center': 'Potassium'}>,
#         <Axes: title={'center': 'VitaminC'}>],
#        [<Axes: title={'center': 'VitaminE'}>,
#         <Axes: title={'center': 'VitaminD'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
sns.violinplot(x = 'Calcium', y = 'Sodium', data=df,split=True)
# Out:
# <Axes: xlabel='Calcium', ylabel='Sodium'>

# %%
df1 = df.drop('Description',axis=1)

# %%
avg_values = df1.mean()

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=avg_values.index, y=avg_values.values)
plt.xticks(rotation=45)
plt.ylabel('Average Value')
plt.title('Average Nutritional Values')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Calories'], bins=10, kde=True)
plt.xlabel('Calories')
plt.ylabel('Frequency')
plt.title('Distribution of Calories')
plt.show()

# %%
df1.corr()
# Out:
#               Calories   Protein  TotalFat  Carbohydrate    Sodium  \
# Calories      1.000000  0.135258  0.807770      0.434701  0.033703
# Protein       0.135258  1.000000  0.061682     -0.284500 -0.003253
# TotalFat      0.807770  0.061682  1.000000     -0.109399  0.003390
# Carbohydrate  0.434701 -0.284500 -0.109399      1.000000  0.049544
# Sodium        0.033703 -0.003253  0.003390      0.049544  1.000000
# SaturatedFat  0.611601  0.045784  0.766142     -0.108676 -0.005075
# Cholesterol   0.032433  0.280578  0.097111     -0.216070 -0.018348
# Sugar         0.309989 -0.289221 -0.055459      0.688422 -0.007078
# Calcium       0.112560  0.041071  0.006585      0.187122  0.174784
# Iron          0.192506  0.133609 -0.051781      0.362023  0.027904
# Potassium     0.078807  0.225451 -0.052801      0.148615 -0.009881
# VitaminC     -0.029628 -0.067523 -0.059612      0.093021 -0.013911
# VitaminE      0.365777 -0.057482  0.370318      0.097550 -0.002742
# ...

# %%
plt.figure(figsize=((15,15)))
sns.heatmap(df1.corr(),cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['Protein', 'TotalFat', 'Carbohydrate']])
plt.ylabel('Nutrient Value')
plt.title('Distribution of Nutrients')
plt.show()

# %% [markdown]
# # Missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7058 entries, 0 to 7057
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Description   7058 non-null   object
#  1   Calories      7057 non-null   float64
#  2   Protein       7057 non-null   float64
#  3   TotalFat      7057 non-null   float64
#  4   Carbohydrate  7057 non-null   float64
#  5   Sodium        6974 non-null   float64
#  6   SaturatedFat  6757 non-null   float64
#  7   Cholesterol   6770 non-null   float64
#  8   Sugar         5148 non-null   float64
#  9   Calcium       6922 non-null   float64
#  10  Iron          6935 non-null   float64
#  11  Potassium     6649 non-null   float64
#  12  VitaminC      6726 non-null   float64
#  13  VitaminE      4338 non-null   float64
#  14  VitaminD      4224 non-null   float64
# dtypes: float64(14), object(1)
# memory usage: 827.2+ KB

# %%
df.isna().sum()
# Out:
# Description        0
# Calories           1
# Protein            1
# TotalFat           1
# Carbohydrate       1
# Sodium            84
# SaturatedFat     301
# Cholesterol      288
# Sugar           1910
# Calcium          136
# Iron             123
# Potassium        409
# VitaminC         332
# VitaminE        2720
# VitaminD        2834
# dtype: int64

# %% [markdown]
# object = mode()[0]
# float = mean/median (by check skewness in histogram)
# if skewness = mean()
# no skewness  = median()

# %%
df.hist(figsize=((15,15)))
# Out:
# array([[<Axes: title={'center': 'Calories'}>,
#         <Axes: title={'center': 'Protein'}>,
#         <Axes: title={'center': 'TotalFat'}>,
#         <Axes: title={'center': 'Carbohydrate'}>],
#        [<Axes: title={'center': 'Sodium'}>,
#         <Axes: title={'center': 'SaturatedFat'}>,
#         <Axes: title={'center': 'Cholesterol'}>,
#         <Axes: title={'center': 'Sugar'}>],
#        [<Axes: title={'center': 'Calcium'}>,
#         <Axes: title={'center': 'Iron'}>,
#         <Axes: title={'center': 'Potassium'}>,
#         <Axes: title={'center': 'VitaminC'}>],
#        [<Axes: title={'center': 'VitaminE'}>,
#         <Axes: title={'center': 'VitaminD'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# keynote :  every column have skewness so its median()

# %%
df.columns
# Out:
# Index(['Description', 'Calories', 'Protein', 'TotalFat', 'Carbohydrate',
#        'Sodium', 'SaturatedFat', 'Cholesterol', 'Sugar', 'Calcium', 'Iron',
#        'Potassium', 'VitaminC', 'VitaminE', 'VitaminD'],
#       dtype='object')

# %%
for i in ['Calories', 'Protein', 'TotalFat', 'Carbohydrate',
       'Sodium', 'SaturatedFat', 'Cholesterol', 'Sugar', 'Calcium', 'Iron',
       'Potassium', 'VitaminC', 'VitaminE', 'VitaminD']:
    df[i] = df[i].fillna(df[i].median())

# %%
df.isna().sum()
# Out:
# Description     0
# Calories        0
# Protein         0
# TotalFat        0
# Carbohydrate    0
# Sodium          0
# SaturatedFat    0
# Cholesterol     0
# Sugar           0
# Calcium         0
# Iron            0
# Potassium       0
# VitaminC        0
# VitaminE        0
# VitaminD        0
# dtype: int64

# %%
df.head(10)
# Out:
#                 Description  Calories  Protein  TotalFat  Carbohydrate  \
# 0          BUTTER,WITH SALT     717.0     0.85     81.11          0.06
# 1  BUTTER,WHIPPED,WITH SALT     717.0     0.85     81.11          0.06
# 2      BUTTER OIL,ANHYDROUS     876.0     0.28     99.48          0.00
# 3               CHEESE,BLUE     353.0    21.40     28.74          2.34
# 4              CHEESE,BRICK     371.0    23.24     29.68          2.79
# 5               CHEESE,BRIE     334.0    20.75     27.68          0.45
# 6          CHEESE,CAMEMBERT     300.0    19.80     24.26          0.46
# 7            CHEESE,CARAWAY     376.0    25.18     29.20          3.06
# 8            CHEESE,CHEDDAR     403.0    24.90     33.14          1.28
# 9           CHEESE,CHESHIRE     387.0    23.37     30.60          4.78
#
#    Sodium  SaturatedFat  Cholesterol  Sugar  Calcium  Iron  Potassium  \
# 0   714.0        51.368        215.0  0.060     24.0  0.02       24.0
# ...

# %% [markdown]
# cleared all null spots in the dataset

# %% [markdown]
# # label Encoding

# %%
df.nunique()
# Out:
# Description     7054
# Calories         655
# Protein         2415
# TotalFat        2151
# Carbohydrate    2758
# Sodium          1196
# SaturatedFat    3213
# Cholesterol      287
# Sugar           1566
# Calcium          498
# Iron             926
# Potassium        885
# VitaminC         529
# VitaminE         485
# VitaminD         113
# dtype: int64

# %% [markdown]
# description have 7054 unique values so id doesnot needed to encoded to numerical

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()

# %%
x = df.drop('Description',axis=1)
y = df['Description']

# %%
newx = minmax.fit_transform(x)

# %%
type(newx)
# Out:
# numpy.ndarray

# %%
df = pd.DataFrame(newx,columns=['Calories', 'Protein', 'TotalFat', 'Carbohydrate',
       'Sodium', 'SaturatedFat', 'Cholesterol', 'Sugar', 'Calcium', 'Iron',
       'Potassium', 'VitaminC', 'VitaminE', 'VitaminD'])

# %%
df = pd.concat([y,df],axis=1)

# %%
df
# Out:
#                      Description  Calories   Protein  TotalFat  Carbohydrate  \
# 0               BUTTER,WITH SALT  0.794900  0.009624    0.8111        0.0006
# 1       BUTTER,WHIPPED,WITH SALT  0.794900  0.009624    0.8111        0.0006
# 2           BUTTER OIL,ANHYDROUS  0.971175  0.003170    0.9948        0.0000
# 3                    CHEESE,BLUE  0.391353  0.242301    0.2874        0.0234
# 4                   CHEESE,BRICK  0.411308  0.263134    0.2968        0.0279
# ...                          ...       ...       ...       ...           ...
# 7053               FROG LEGS,RAW  0.080931  0.185688    0.0030        0.0000
# 7054             MACKEREL,SALTED  0.338137  0.209466    0.2510        0.0000
# 7055  SCALLOP,(BAY&SEA),CKD,STMD  0.123060  0.232563    0.0084        0.0541
# 7056                   SNAIL,RAW  0.099778  0.182292    0.0140        0.0200
# 7057            TURTLE,GREEN,RAW  0.098670  0.224185    0.0050        0.0000
#
# ...

# %%
df.tail()
# Out:
#                      Description  Calories   Protein  TotalFat  Carbohydrate  \
# 7053               FROG LEGS,RAW  0.080931  0.185688    0.0030        0.0000
# 7054             MACKEREL,SALTED  0.338137  0.209466    0.2510        0.0000
# 7055  SCALLOP,(BAY&SEA),CKD,STMD  0.123060  0.232563    0.0084        0.0541
# 7056                   SNAIL,RAW  0.099778  0.182292    0.0140        0.0200
# 7057            TURTLE,GREEN,RAW  0.098670  0.224185    0.0050        0.0000
#
#         Sodium  SaturatedFat  Cholesterol  Sugar   Calcium      Iron  \
# 7053  0.001496      0.000795     0.016129    0.0  0.002444  0.012136
# 7054  0.114815      0.074770     0.030645    0.0  0.008963  0.011327
# 7055  0.017209      0.002280     0.013226    0.0  0.001358  0.004693
# 7056  0.001806      0.003776     0.016129    0.0  0.001358  0.028317
# 7057  0.001754      0.001328     0.016129    0.0  0.016024  0.011327
#
#       Potassium  VitaminC  VitaminE  VitaminD
# ...

# %% [markdown]
# key takeaways :

# %% [markdown]
# Butter vs. Cheese:
# The provided subset includes various forms of butter and different types of cheese. While butter generally has higher total fat content, cheese tends to contain more protein and calcium. This trend is consistent with the larger dataset and highlights the differences in nutritional composition between these dairy products.
#
# Effect of Processing:
# Comparing different variations of butter, such as whipped butter and butter oil, reveals slight variations in nutritional content. For example, whipped butter appears to have marginally higher sodium content compared to regular butter. Further analysis of processed vs. unprocessed forms of dairy products can provide insights into how processing techniques affect nutritional profiles.
#
# Variability in Sodium Content:
# There's noticeable variability in sodium content across the subset. For instance, blue cheese has relatively lower sodium content compared to other food items like whipped butter. This variability underscores the importance of considering sodium levels when making dietary choices, especially for individuals monitoring their sodium intake.
#
# Nutrient Density:
# Analyzing the nutrient density of different foods can help identify healthier options. For example, foods with higher protein and lower saturated fat content, such as certain types of cheese, may be considered more nutrient-dense choices.
#
# Calcium and Bone Health:
# Cheese, such as blue cheese and brick cheese, stands out as a significant source of calcium. This observation reinforces the importance of including calcium-rich foods in the diet to support bone health and prevent conditions like osteoporosis.
#
# Fat Content and Calories:
# The provided subset confirms that butter and cheese are calorie-dense foods due to their high fat content. This information can be valuable for individuals managing their calorie intake or following specific dietary plans.
#
# Cholesterol Levels:
# Butter tends to have higher cholesterol levels compared to cheese, as evident from the subset. This finding is consistent with broader dietary recommendations to limit cholesterol intake, particularly from sources like butter.
#
# Micronutrient Variation:
# In addition to macronutrients, the subset includes micronutrients like iron, potassium, and vitamins. Analyzing the variation in micronutrient content across different foods can offer insights into their overall nutritional quality and potential health benefits.
